# %% [markdown]
# <a href="https://colab.research.google.com/github/gazm/jupyter-notebooks/blob/main/crypto_charts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Plan**
#
#
# > Violin visualization on candlesticks (volume)
# > ![Screenshot (51).png](data:image/png;base64,...)
